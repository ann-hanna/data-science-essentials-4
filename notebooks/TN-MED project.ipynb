# %%
import pandas as pd

# %%
hospitals = pd.read_csv('../data/Hospitals.csv')

# %%
hospitals.head()
# Out:
#               X             Y  OBJECTID        ID  \
# 0 -1.331889e+07  4.346975e+06         1   5793230
# 1 -1.322651e+07  4.049626e+06         2  53391362
# 2 -1.315620e+07  4.031978e+06         3  11190023
# 3 -1.317190e+07  4.041752e+06         4  17090028
# 4 -1.313208e+07  4.037270e+06         5  23691706
#
#                                                 NAME  \
# 0                    CENTRAL VALLEY GENERAL HOSPITAL
# 1  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 2                  EAST LOS ANGELES DOCTORS HOSPITAL
# 3          SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# 4                      KINDRED HOSPITAL BALDWIN PARK
#
#                      ADDRESS             CITY STATE    ZIP           ZIP4  \
# 0    1025 NORTH DOUTY STREET          HANFORD    CA  93230  NOT AVAILABLE
# 1             150 VIA MERIDA  WESTLAKE VILAGE    CA  91362  NOT AVAILABLE
# 2    4060 WHITTIER BOULEVARD      LOS ANGELES    CA  90023  NOT AVAILABLE
# ...

# %%
hospitals.shape
# Out:
# (7596, 34)

# %%
hospitals[["CITY","STATE","TYPE","STATUS","POPULATION","COUNTY","COUNTYFIPS","BEDS"]]
# Out:
#             CITY STATE                TYPE  STATUS  POPULATION      COUNTY  \
# 515       ETOWAH    TN  GENERAL ACUTE CARE    OPEN          72      MCMINN
# 535   GAINESBORO    TN  GENERAL ACUTE CARE  CLOSED        -999     JACKSON
# 536     COLUMBIA    TN  GENERAL ACUTE CARE    OPEN         255       MAURY
# 537      JACKSON    TN  GENERAL ACUTE CARE    OPEN         152     MADISON
# 540        PARIS    TN  GENERAL ACUTE CARE    OPEN         142       HENRY
# ...          ...   ...                 ...     ...         ...         ...
# 6810    PORTLAND    TN  GENERAL ACUTE CARE    OPEN         159      SUMNER
# 6811      SMYRNA    TN  GENERAL ACUTE CARE    OPEN         109  RUTHERFORD
# 6812       ERWIN    TN  GENERAL ACUTE CARE    OPEN          10      UNICOI
# 6813   NASHVILLE    TN  GENERAL ACUTE CARE    OPEN        1091    DAVIDSON
# 7362       ERWIN    TN  GENERAL ACUTE CARE    OPEN          10      UNICOI
#
#      COUNTYFIPS  BEDS
# 515       47107    72
# ...

# %%
hospitals = hospitals.loc[hospitals['STATE'] == 'TN']
hospitals.shape
# Out:
# (171, 34)

# %%
hospitals.head()
# Out:
#                 X             Y  OBJECTID        ID  \
# 515 -9.409026e+06  4.210878e+06       517  14737331
# 535 -9.535209e+06  4.348723e+06       537   3438562
# 536 -9.692242e+06  4.246701e+06       538   8038401
# 537 -9.891187e+06  4.257288e+06       539   8338305
# 540 -9.830658e+06  4.341502e+06       542   6538242
#
#                                          NAME                ADDRESS  \
# 515      STARR REGIONAL MEDICAL CENTER ETOWAH  886 HIGHWAY 411 NORTH
# 535                   JACKSON COUNTY HOSPITAL     620 HOSPITAL DRIVE
# 536                   MAURY REGIONAL HOSPITAL   1224 TROTWOOD AVENUE
# 537  WEST TENNESSEE HEALTHCARE NORTH HOSPITAL     367 HOSPITAL BLVD.
# 540               HENRY COUNTY MEDICAL CENTER       301 TYSON AVENUE
#
#            CITY STATE    ZIP           ZIP4  ...             VAL_DATE  \
# 515      ETOWAH    TN  37331  NOT AVAILABLE  ...  2014/02/10 00:00:00
# 535  GAINESBORO    TN  38562  NOT AVAILABLE  ...  2014/02/12 00:00:00
# ...

# %%
hospitals.loc[hospitals['STATUS'] == 'OPEN']
hospitals.shape
# Out:
# (171, 34)

# %%
hospitals['COUNTY'].value_counts()
# Out:
# SHELBY        23
# DAVIDSON      15
# HAMILTON      13
# KNOX          11
# WASHINGTON     6
#               ..
# CARTER         1
# WARREN         1
# CLAY           1
# SMITH          1
# WAYNE          1
# Name: COUNTY, Length: 80, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
hospitals['COUNTY'].value_counts().plot(kind = 'hist')
plt.xlim([0, 25])
plt.ylim([0, 75])
plt.yticks(np.arange(1,80,10))
plt.xticks(np.arange(1,25,1))

plt.show()

# %%
hospitals.groupby([ "COUNTY"]).size()
# Out:
# COUNTY
# ANDERSON      1
# BEDFORD       2
# BENTON        1
# BLEDSOE       1
# BLOUNT        2
#              ..
# WAYNE         1
# WEAKLEY       2
# WHITE         1
# WILLIAMSON    2
# WILSON        2
# Length: 80, dtype: int64

# %%
hospitals.groupby([ "COUNTY", "BEDS"]).size()
# Out:
# COUNTY      BEDS
# ANDERSON    301     1
# BEDFORD     60      1
#             177     1
# BENTON      25      1
# BLEDSOE     25      1
#                    ..
# WEAKLEY     100     1
# WHITE       60      1
# WILLIAMSON  40      1
#             185     1
# WILSON      245     2
# Length: 164, dtype: int64

# %%
hospital_count_tn_counties = hospitals['COUNTY'].value_counts()
.reset_index(name ='hospitals_per_county').rename(columns = {'index':'county'})
# Out:
#   File "/var/folders/mt/qlbxfqq91hnf52hdpzzy8nl00000gn/T/ipykernel_27144/16300729.py", line 2
#     .reset_index(name ='hospitals_per_county').rename(columns = {'index':'county'})
#     ^
# SyntaxError: invalid syntax

# %%
hospital_count_tn_counties.head()
# Out:
#         index  hospitals_per_county
# 0      SHELBY                    23
# 1    DAVIDSON                    15
# 2    HAMILTON                    13
# 3        KNOX                    11
# 4  WASHINGTON                     6

# %%
hospital_beds_tn_counties = hospitals.groupby([ "COUNTY", "BEDS"]).size().reset_index()

hospital_beds_tn_counties.shape
# Out:
# (164, 3)

# %%
hospital_count_tn_counties.sort_values(by='index')
# Out:
#          index  hospitals_per_county
# 32    ANDERSON                     1
# 19     BEDFORD                     2
# 34      BENTON                     1
# 31     BLEDSOE                     1
# 22      BLOUNT                     2
# ..         ...                   ...
# 79       WAYNE                     1
# 16     WEAKLEY                     2
# 40       WHITE                     1
# 23  WILLIAMSON                     2
# 14      WILSON                     2
#
# [80 rows x 2 columns]

# %%
hospital_count_tn_counties.sort_values(by='index')
# Out:
#          index  hospitals_per_county
# 32    ANDERSON                     1
# 19     BEDFORD                     2
# 34      BENTON                     1
# 31     BLEDSOE                     1
# 22      BLOUNT                     2
# ..         ...                   ...
# 79       WAYNE                     1
# 16     WEAKLEY                     2
# 40       WHITE                     1
# 23  WILLIAMSON                     2
# 14      WILSON                     2
#
# [80 rows x 2 columns]

# %%
physicians = pd.read_csv('../data/primary_care_physicians.csv')

# %%
physicians.head()
# Out:
#    FIPS    state   county  primary_care_physicians
# 0  1001  Alabama  Autauga                     26.0
# 1  1003  Alabama  Baldwin                    153.0
# 2  1005  Alabama  Barbour                      8.0
# 3  1007  Alabama     Bibb                     12.0
# 4  1009  Alabama   Blount                     12.0

# %%
physicians = physicians.loc[physicians['state'] == 'Tennessee']

# %%
physicians.head()
# Out:
#        FIPS      state    county  primary_care_physicians
# 2432  47001  Tennessee  Anderson                     39.0
# 2433  47003  Tennessee   Bedford                     15.0
# 2434  47005  Tennessee    Benton                      3.0
# 2435  47007  Tennessee   Bledsoe                      1.0
# 2436  47009  Tennessee    Blount                     90.0

# %%
hospitals['index'].str.lower()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/geo_dse/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/envs/geo_dse/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/envs/geo_dse/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
pd.merge(left = physicians, 
         right = hospital_count_tn_counties,
         left_on = 'county', 
         right_on = 'index',
         how = 'outer')
# Out:
#         FIPS      state    county  primary_care_physicians   index  \
# 0    47001.0  Tennessee  Anderson                     39.0     NaN
# 1    47003.0  Tennessee   Bedford                     15.0     NaN
# 2    47005.0  Tennessee    Benton                      3.0     NaN
# 3    47007.0  Tennessee   Bledsoe                      1.0     NaN
# 4    47009.0  Tennessee    Blount                     90.0     NaN
# ..       ...        ...       ...                      ...     ...
# 170      NaN        NaN       NaN                      NaN  CARTER
# 171      NaN        NaN       NaN                      NaN  WARREN
# 172      NaN        NaN       NaN                      NaN    CLAY
# 173      NaN        NaN       NaN                      NaN   SMITH
# 174      NaN        NaN       NaN                      NaN   WAYNE
#
#      hospitals_per_county
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# ...

# %%
merge = pd.merge(left = physicians,
         right = hospital_count_tn_counties.rename(columns = {“COUNTY”: “county”}),
         on=“county”,
        how=“left”
        )
# Out:
#   File "/var/folders/mt/qlbxfqq91hnf52hdpzzy8nl00000gn/T/ipykernel_27144/3126028888.py", line 2
#     right = hospital_count_tn_counties.rename(columns = {“COUNTY”: “county”}),
#                                                          ^
# SyntaxError: invalid character '“' (U+201C)

# %%
'help_counties = physicians.loc[(physicians['shadac_category'] == 'low inadequate') & (physicians['pcp_per_100k'] < 26.13)]
help_counties.head()'
# Out:
#   File "/var/folders/mt/qlbxfqq91hnf52hdpzzy8nl00000gn/T/ipykernel_27144/2263690286.py", line 1
#     'help_counties = physicians.loc[(physicians['shadac_category'] == 'low inadequate') & (physicians['pcp_per_100k'] < 26.13)]
#                                                  ^
# SyntaxError: invalid syntax
